# %% [markdown]
# # Important Libraries

# %% [markdown]
# 1. Pandas- To handle data (like MS Excel)
# 2. Numpy
# 3. Seaborn
# 4. Plotly
# 5. Matplotlib
# 6. Scipy.stats
# 7. Scikit_learn
# 8. Streamlit

# %% [markdown]
# # Installing Libraries
#
# * To install these libraries , you can use pip install library_name command in your terminal.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
pd.read_excel

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Boxen Plot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(
    diamonds, x="clarity", y="carat",
    color="b", order=clarity_ranking, width_method="linear",
)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>
